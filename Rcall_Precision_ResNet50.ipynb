# %% [markdown]
# <a href="https://colab.research.google.com/github/aaron020/CNN_Project/blob/main/Rcall_Precision_ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://github.com/pythonlessons/Keras-ResNet-tutorial/blob/master/Keras-ResNet-tutorial.ipynb

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import cv2
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, Dropout
from keras.models import Model, load_model
from keras.initializers import glorot_uniform
from keras.utils import plot_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from matplotlib import pyplot as plt
import keras.backend as K
import tensorflow as tf

# %%
#Rows and cols = the size of the image, channels = RGB and classes is dog and cat 
ROWS = 128
COLS = 128
CHANNELS = 3
CLASSES = 2

# %%
#!unzip drive/MyDrive/archive.zip

#from google.colab import drive
#drive.mount('/content/drive')

# %%
#pull in a dataset from content 
pathNameTraining = "training_set/training_set"
pathNameTest = "test_set/test_set"

#!unzip archive.zip
Training_types = os.listdir(pathNameTraining)
test_types = os.listdir(pathNameTest)

print("Training folders = " , Training_types)
print("Test folders = " , test_types)
# Out:
# Training folders =  ['cats', 'dogs']
# Test folders =  ['cats', 'dogs']

# %%
def read_image(file_path):
    #Read in the image, in colour 
    img = cv2.imread(file_path, cv2.IMREAD_COLOR)
    #Return the image, resized to be 224 x 224   
    return cv2.resize(img, (ROWS, COLS), interpolation=cv2.INTER_CUBIC)

def prepare_data(images):
    m = len(images)
    X = np.zeros((m, ROWS, COLS, CHANNELS), dtype=np.uint8)
    y = np.zeros((1, m), dtype=np.uint8)
    for i, image_file in enumerate(images):
        X[i,:] = read_image(image_file)
        if 'dogs' in image_file.lower():
            y[0, i] = 1
        elif 'cats' in image_file.lower():
            y[0, i] = 0
    return X, y

def convert_to_one_hot(Y, C):
    Y = np.eye(C)[Y.reshape(-1)].T
    return Y

# %%
#Tack all the data from the datset 
TRAIN_DIR = []
TEST_DIR = []

for item in Training_types:
  # get all the files from each folder 
  all_training = os.listdir(pathNameTraining + '/' + item)
  #Half the dataset due to ram problems
  for fw in range(len(all_training)):
    #Some of the training set is not jpg which causes errors for the resize
    if 'jpg' in all_training[fw]:
      name = pathNameTraining + '/' + item + '/' + all_training[fw]
      TRAIN_DIR.append(name)


import random 

random.shuffle(TRAIN_DIR)


for sample in TRAIN_DIR[:10]:
  print(sample)


for item in test_types:
  # get all the files from each folder 
  all_test = os.listdir(pathNameTest + '/' + item)
  #Half the dataset due to ram problems
  for fw in range(len(all_test)):
    if 'jpg' in all_test[fw]:
      name = pathNameTest + '/' + item + '/' + all_test[fw]
      TEST_DIR.append(name)

random.shuffle(TEST_DIR)

print(len(TRAIN_DIR))
print(len(TEST_DIR))
# Out:
# training_set/training_set/dogs/dog.1416.jpg
# training_set/training_set/dogs/dog.1665.jpg
# training_set/training_set/dogs/dog.2954.jpg
# training_set/training_set/cats/cat.1298.jpg
# training_set/training_set/dogs/dog.1438.jpg
# training_set/training_set/dogs/dog.1032.jpg
# training_set/training_set/dogs/dog.166.jpg
# training_set/training_set/cats/cat.811.jpg
# training_set/training_set/cats/cat.2537.jpg
# training_set/training_set/dogs/dog.2129.jpg
# 8005
# 2023

# %%
train_set_x, train_set_y = prepare_data(TRAIN_DIR)
test_set_x, test_set_y = prepare_data(TEST_DIR)


Y_train = convert_to_one_hot(train_set_y, CLASSES).T
Y_test = convert_to_one_hot(test_set_y, CLASSES).T



for sample in train_set_x[:2]:
  plt.imshow(sample)
  plt.show()

# %%
X_train = train_set_x/255
X_test = test_set_x/255

# %%
print(len(train_set_y[0]))
# Out:
# 8005

# %%
print ("number of training examples =", X_train.shape[0])
print ("number of test examples =", X_test.shape[0])
print ("X_train shape:", X_train.shape)
print ("Y_train shape:", Y_train.shape)
print ("X_test shape:", X_test.shape)
print ("Y_test shape:", Y_test.shape)
# Out:
# number of training examples = 8005
# number of test examples = 2023
# X_train shape: (8005, 128, 128, 3)
# Y_train shape: (8005, 2)
# X_test shape: (2023, 128, 128, 3)
# Y_test shape: (2023, 2)

# %%
def identity_block(X, f, filters, stage, block):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value. We'll need this later to add back to the main path. 
    X_shortcut = X

    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    #X = Dropout(.5)(X)

    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)
    #X = Dropout(.5)(X)

    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    #X = Dropout(.5)(X)
   


    # Second component of main path
    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)
    #X = Dropout(.5)(X)
    

    # Third component of main path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    
    ##### SHORTCUT PATH ####
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
def ResNet50(input_shape = (224, 224, 3), classes = 2):   
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    # Stage 3
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    # Stage 4
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    # Stage 5
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    # AVGPOOL.
    X = AveragePooling2D((2, 2), name='avg_pool')(X)

    # output layer
    X = Flatten()(X)

    #X = Dropout(.2)(X)

    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    return model

# %%
model = ResNet50(input_shape = (ROWS, COLS, CHANNELS), classes = CLASSES)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# %%
#For example: validation_split=0.3 will cause that 30% of the training data will be used for validation.
history = model.fit(X_train, Y_train, epochs = 50, validation_split=0.2,batch_size = 32)
# Out:
# Epoch 1/50
# 201/201 [==============================] - 15s 45ms/step - loss: 1.5174 - accuracy: 0.5418 - precision_2: 0.5418 - recall_1: 0.5418 - val_loss: 0.8733 - val_accuracy: 0.4878 - val_precision_2: 0.4878 - val_recall_1: 0.4878
# Epoch 2/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.9425 - accuracy: 0.5942 - precision_2: 0.5942 - recall_1: 0.5942 - val_loss: 0.6752 - val_accuracy: 0.5796 - val_precision_2: 0.5796 - val_recall_1: 0.5796
# Epoch 3/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.7274 - accuracy: 0.6640 - precision_2: 0.6640 - recall_1: 0.6640 - val_loss: 0.7714 - val_accuracy: 0.5909 - val_precision_2: 0.5909 - val_recall_1: 0.5909
# Epoch 4/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.6674 - accuracy: 0.6993 - precision_2: 0.6993 - recall_1: 0.6993 - val_loss: 0.9904 - val_accuracy: 0.5290 - val_precision_2: 0.5290 - val_recall_1: 0.5290
# Epoch 5/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.6317 - accuracy: 0.6938 - precision_2: 0.6938 - recall_1: 0.6938 - val_loss: 0.6291 - val_accuracy: 0.6646 - val_precision_2: 0.6646 - val_recall_1: 0.6646
# Epoch 6/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.7296 - accuracy: 0.6616 - precision_2: 0.6616 - recall_1: 0.6616 - val_loss: 1.2924 - val_accuracy: 0.5097 - val_precision_2: 0.5097 - val_recall_1: 0.5097
# Epoch 7/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.6356 - accuracy: 0.6944 - precision_2: 0.6944 - recall_1: 0.6944 - val_loss: 2.5935 - val_accuracy: 0.6052 - val_precision_2: 0.6052 - val_recall_1: 0.6052
# Epoch 8/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5609 - accuracy: 0.7306 - precision_2: 0.7306 - recall_1: 0.7306 - val_loss: 1.3480 - val_accuracy: 0.6002 - val_precision_2: 0.6002 - val_recall_1: 0.6002
# Epoch 9/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5709 - accuracy: 0.7411 - precision_2: 0.7411 - recall_1: 0.7411 - val_loss: 1.0490 - val_accuracy: 0.5415 - val_precision_2: 0.5415 - val_recall_1: 0.5415
# Epoch 10/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5804 - accuracy: 0.7214 - precision_2: 0.7214 - recall_1: 0.7214 - val_loss: 8.9161 - val_accuracy: 0.5028 - val_precision_2: 0.5028 - val_recall_1: 0.5028
# Epoch 11/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5612 - accuracy: 0.7358 - precision_2: 0.7358 - recall_1: 0.7358 - val_loss: 0.5691 - val_accuracy: 0.7027 - val_precision_2: 0.7027 - val_recall_1: 0.7027
# Epoch 12/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.6428 - accuracy: 0.6644 - precision_2: 0.6644 - recall_1: 0.6644 - val_loss: 1.3748 - val_accuracy: 0.4897 - val_precision_2: 0.4897 - val_recall_1: 0.4897
# Epoch 13/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.6606 - accuracy: 0.6597 - precision_2: 0.6597 - recall_1: 0.6597 - val_loss: 2.4034 - val_accuracy: 0.5628 - val_precision_2: 0.5628 - val_recall_1: 0.5628
# Epoch 14/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5972 - accuracy: 0.7024 - precision_2: 0.7024 - recall_1: 0.7024 - val_loss: 0.6745 - val_accuracy: 0.6783 - val_precision_2: 0.6783 - val_recall_1: 0.6783
# Epoch 15/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5520 - accuracy: 0.7363 - precision_2: 0.7363 - recall_1: 0.7363 - val_loss: 1.3002 - val_accuracy: 0.5403 - val_precision_2: 0.5403 - val_recall_1: 0.5403
# Epoch 16/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5662 - accuracy: 0.7224 - precision_2: 0.7224 - recall_1: 0.7224 - val_loss: 1.6132 - val_accuracy: 0.5109 - val_precision_2: 0.5109 - val_recall_1: 0.5109
# Epoch 17/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5128 - accuracy: 0.7636 - precision_2: 0.7636 - recall_1: 0.7636 - val_loss: 0.6677 - val_accuracy: 0.6615 - val_precision_2: 0.6615 - val_recall_1: 0.6615
# Epoch 18/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5089 - accuracy: 0.7706 - precision_2: 0.7706 - recall_1: 0.7706 - val_loss: 0.6777 - val_accuracy: 0.6889 - val_precision_2: 0.6889 - val_recall_1: 0.6889
# Epoch 19/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5267 - accuracy: 0.7572 - precision_2: 0.7572 - recall_1: 0.7572 - val_loss: 0.7903 - val_accuracy: 0.6708 - val_precision_2: 0.6708 - val_recall_1: 0.6708
# Epoch 20/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5721 - accuracy: 0.7442 - precision_2: 0.7442 - recall_1: 0.7442 - val_loss: 0.9199 - val_accuracy: 0.6146 - val_precision_2: 0.6146 - val_recall_1: 0.6146
# Epoch 21/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.4238 - accuracy: 0.7976 - precision_2: 0.7976 - recall_1: 0.7976 - val_loss: 0.7320 - val_accuracy: 0.6433 - val_precision_2: 0.6433 - val_recall_1: 0.6433
# Epoch 22/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.5084 - accuracy: 0.7559 - precision_2: 0.7559 - recall_1: 0.7559 - val_loss: 0.5881 - val_accuracy: 0.7096 - val_precision_2: 0.7096 - val_recall_1: 0.7096
# Epoch 23/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.4216 - accuracy: 0.8150 - precision_2: 0.8150 - recall_1: 0.8150 - val_loss: 0.6897 - val_accuracy: 0.7270 - val_precision_2: 0.7270 - val_recall_1: 0.7270
# Epoch 24/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.3741 - accuracy: 0.8349 - precision_2: 0.8349 - recall_1: 0.8349 - val_loss: 1.2347 - val_accuracy: 0.5509 - val_precision_2: 0.5509 - val_recall_1: 0.5509
# Epoch 25/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.3130 - accuracy: 0.8648 - precision_2: 0.8648 - recall_1: 0.8648 - val_loss: 0.5275 - val_accuracy: 0.7689 - val_precision_2: 0.7689 - val_recall_1: 0.7689
# Epoch 26/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.2844 - accuracy: 0.8745 - precision_2: 0.8745 - recall_1: 0.8745 - val_loss: 0.9439 - val_accuracy: 0.6683 - val_precision_2: 0.6683 - val_recall_1: 0.6683
# Epoch 27/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.2603 - accuracy: 0.8852 - precision_2: 0.8852 - recall_1: 0.8852 - val_loss: 0.7470 - val_accuracy: 0.7539 - val_precision_2: 0.7539 - val_recall_1: 0.7539
# Epoch 28/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.2121 - accuracy: 0.9096 - precision_2: 0.9096 - recall_1: 0.9096 - val_loss: 0.9418 - val_accuracy: 0.6983 - val_precision_2: 0.6983 - val_recall_1: 0.6983
# Epoch 29/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.1958 - accuracy: 0.9172 - precision_2: 0.9172 - recall_1: 0.9172 - val_loss: 0.7092 - val_accuracy: 0.7433 - val_precision_2: 0.7433 - val_recall_1: 0.7433
# Epoch 30/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.1796 - accuracy: 0.9302 - precision_2: 0.9302 - recall_1: 0.9302 - val_loss: 1.2453 - val_accuracy: 0.7651 - val_precision_2: 0.7651 - val_recall_1: 0.7651
# Epoch 31/50
# 201/201 [==============================] - 8s 39ms/step - loss: 0.1493 - accuracy: 0.9405 - precision_2: 0.9405 - recall_1: 0.9405 - val_loss: 0.7183 - val_accuracy: 0.7776 - val_precision_2: 0.7776 - val_recall_1: 0.7776
# Epoch 32/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.1245 - accuracy: 0.9502 - precision_2: 0.9502 - recall_1: 0.9502 - val_loss: 1.1393 - val_accuracy: 0.7108 - val_precision_2: 0.7108 - val_recall_1: 0.7108
# Epoch 33/50
# 201/201 [==============================] - 8s 39ms/step - loss: 0.1177 - accuracy: 0.9544 - precision_2: 0.9544 - recall_1: 0.9544 - val_loss: 0.7125 - val_accuracy: 0.7614 - val_precision_2: 0.7614 - val_recall_1: 0.7614
# Epoch 34/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.1141 - accuracy: 0.9527 - precision_2: 0.9527 - recall_1: 0.9527 - val_loss: 1.7324 - val_accuracy: 0.6508 - val_precision_2: 0.6508 - val_recall_1: 0.6508
# Epoch 35/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.1066 - accuracy: 0.9622 - precision_2: 0.9622 - recall_1: 0.9622 - val_loss: 0.9667 - val_accuracy: 0.7633 - val_precision_2: 0.7633 - val_recall_1: 0.7633
# Epoch 36/50
# 201/201 [==============================] - 8s 39ms/step - loss: 0.0757 - accuracy: 0.9735 - precision_2: 0.9735 - recall_1: 0.9735 - val_loss: 1.3000 - val_accuracy: 0.7514 - val_precision_2: 0.7514 - val_recall_1: 0.7514
# Epoch 37/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0734 - accuracy: 0.9731 - precision_2: 0.9731 - recall_1: 0.9731 - val_loss: 0.9751 - val_accuracy: 0.7689 - val_precision_2: 0.7689 - val_recall_1: 0.7689
# Epoch 38/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0757 - accuracy: 0.9710 - precision_2: 0.9710 - recall_1: 0.9710 - val_loss: 1.1590 - val_accuracy: 0.7595 - val_precision_2: 0.7595 - val_recall_1: 0.7595
# Epoch 39/50
# 201/201 [==============================] - 8s 39ms/step - loss: 0.0609 - accuracy: 0.9772 - precision_2: 0.9772 - recall_1: 0.9772 - val_loss: 1.0148 - val_accuracy: 0.7858 - val_precision_2: 0.7858 - val_recall_1: 0.7858
# Epoch 40/50
# 201/201 [==============================] - 8s 39ms/step - loss: 0.0781 - accuracy: 0.9716 - precision_2: 0.9716 - recall_1: 0.9716 - val_loss: 0.8479 - val_accuracy: 0.8032 - val_precision_2: 0.8032 - val_recall_1: 0.8032
# Epoch 41/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0502 - accuracy: 0.9802 - precision_2: 0.9802 - recall_1: 0.9802 - val_loss: 0.8421 - val_accuracy: 0.8120 - val_precision_2: 0.8120 - val_recall_1: 0.8120
# Epoch 42/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0311 - accuracy: 0.9889 - precision_2: 0.9889 - recall_1: 0.9889 - val_loss: 0.9666 - val_accuracy: 0.7601 - val_precision_2: 0.7601 - val_recall_1: 0.7601
# Epoch 43/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0538 - accuracy: 0.9797 - precision_2: 0.9797 - recall_1: 0.9797 - val_loss: 1.1004 - val_accuracy: 0.7833 - val_precision_2: 0.7833 - val_recall_1: 0.7833
# Epoch 44/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0833 - accuracy: 0.9730 - precision_2: 0.9730 - recall_1: 0.9730 - val_loss: 1.0828 - val_accuracy: 0.7851 - val_precision_2: 0.7851 - val_recall_1: 0.7851
# Epoch 45/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.1069 - accuracy: 0.9589 - precision_2: 0.9589 - recall_1: 0.9589 - val_loss: 23.4487 - val_accuracy: 0.6152 - val_precision_2: 0.6152 - val_recall_1: 0.6152
# Epoch 46/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0681 - accuracy: 0.9750 - precision_2: 0.9750 - recall_1: 0.9750 - val_loss: 0.9978 - val_accuracy: 0.8107 - val_precision_2: 0.8107 - val_recall_1: 0.8107
# Epoch 47/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0556 - accuracy: 0.9808 - precision_2: 0.9808 - recall_1: 0.9808 - val_loss: 2.2962 - val_accuracy: 0.7202 - val_precision_2: 0.7202 - val_recall_1: 0.7202
# Epoch 48/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.1090 - accuracy: 0.9578 - precision_2: 0.9578 - recall_1: 0.9578 - val_loss: 0.9525 - val_accuracy: 0.7714 - val_precision_2: 0.7714 - val_recall_1: 0.7714
# Epoch 49/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0391 - accuracy: 0.9859 - precision_2: 0.9859 - recall_1: 0.9859 - val_loss: 1.0027 - val_accuracy: 0.7726 - val_precision_2: 0.7726 - val_recall_1: 0.7726
# Epoch 50/50
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0968 - accuracy: 0.9642 - precision_2: 0.9642 - recall_1: 0.9642 - val_loss: 0.7747 - val_accuracy: 0.7770 - val_precision_2: 0.7770 - val_recall_1: 0.7770

# %%
plt.figure(figsize=(10,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')


plt.savefig("accuracy_graph.png")

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.savefig("loss_graph.png")

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(history.history['precision_2'])
plt.plot(history.history['val_precision_2'])
plt.title('model Precision')
plt.ylabel('Precision')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.savefig("precision_graph.png")

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(history.history['recall_1'])
plt.plot(history.history['val_recall_1'])
plt.title('model Recall')
plt.ylabel('Recall')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.savefig("Recall_graph.png")

plt.show()

# %%
preds = model.evaluate(X_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
