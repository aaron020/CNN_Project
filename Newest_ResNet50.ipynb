# %% [markdown]
# <a href="https://colab.research.google.com/github/aaron020/CNN_Project/blob/main/Newest_ResNet50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://github.com/pythonlessons/Keras-ResNet-tutorial/blob/master/Keras-ResNet-tutorial.ipynb

import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'
import cv2
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, Dropout
from keras.models import Model, load_model
from keras.initializers import glorot_uniform
from keras.utils import plot_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from matplotlib import pyplot as plt
import keras.backend as K
import tensorflow as tf

# %%
#Rows and cols = the size of the image, channels = RGB and classes is dog and cat 
ROWS = 128
COLS = 128
CHANNELS = 3
CLASSES = 2

# %%
#!unzip drive/MyDrive/archive.zip

#from google.colab import drive
#drive.mount('/content/drive')

# %%
#pull in a dataset from content 
pathNameTraining = "training_set/training_set"
pathNameTest = "test_set/test_set"

#!unzip archive.zip
Training_types = os.listdir(pathNameTraining)
test_types = os.listdir(pathNameTest)

print("Training folders = " , Training_types)
print("Test folders = " , test_types)
# Out:
# Training folders =  ['cats', 'dogs']
# Test folders =  ['cats', 'dogs']

# %%
def read_image(file_path):
    #Read in the image, in colour 
    img = cv2.imread(file_path, cv2.IMREAD_COLOR)
    #Return the image, resized to be 224 x 224   
    return cv2.resize(img, (ROWS, COLS), interpolation=cv2.INTER_CUBIC)

def prepare_data(images):
    m = len(images)
    X = np.zeros((m, ROWS, COLS, CHANNELS), dtype=np.uint8)
    y = np.zeros((1, m), dtype=np.uint8)
    for i, image_file in enumerate(images):
        X[i,:] = read_image(image_file)
        if 'dogs' in image_file.lower():
            y[0, i] = 1
        elif 'cats' in image_file.lower():
            y[0, i] = 0
    return X, y

def convert_to_one_hot(Y, C):
    Y = np.eye(C)[Y.reshape(-1)].T
    return Y

# %%
#Tack all the data from the datset 
TRAIN_DIR = []
TEST_DIR = []

for item in Training_types:
  # get all the files from each folder 
  all_training = os.listdir(pathNameTraining + '/' + item)
  #Half the dataset due to ram problems
  for fw in range(len(all_training)):
    #Some of the training set is not jpg which causes errors for the resize
    if 'jpg' in all_training[fw]:
      name = pathNameTraining + '/' + item + '/' + all_training[fw]
      TRAIN_DIR.append(name)


import random 

random.shuffle(TRAIN_DIR)


for sample in TRAIN_DIR[:10]:
  print(sample)


for item in test_types:
  # get all the files from each folder 
  all_test = os.listdir(pathNameTest + '/' + item)
  #Half the dataset due to ram problems
  for fw in range(len(all_test)):
    if 'jpg' in all_test[fw]:
      name = pathNameTest + '/' + item + '/' + all_test[fw]
      TEST_DIR.append(name)

random.shuffle(TEST_DIR)

print(len(TRAIN_DIR))
print(len(TEST_DIR))
# Out:
# training_set/training_set/dogs/dog.3834.jpg
# training_set/training_set/dogs/dog.3224.jpg
# training_set/training_set/cats/cat.245.jpg
# training_set/training_set/cats/cat.806.jpg
# training_set/training_set/dogs/dog.2401.jpg
# training_set/training_set/dogs/dog.537.jpg
# training_set/training_set/dogs/dog.1071.jpg
# training_set/training_set/dogs/dog.2456.jpg
# training_set/training_set/cats/cat.856.jpg
# training_set/training_set/cats/cat.3490.jpg
# 8005
# 2023

# %%
train_set_x, train_set_y = prepare_data(TRAIN_DIR)
test_set_x, test_set_y = prepare_data(TEST_DIR)


Y_train = convert_to_one_hot(train_set_y, CLASSES).T
Y_test = convert_to_one_hot(test_set_y, CLASSES).T



for sample in train_set_x[:2]:
  plt.imshow(sample)
  plt.show()

# %%
X_train = train_set_x/255
X_test = test_set_x/255

# %%
print(len(train_set_y[0]))
# Out:
# 8005

# %%
print ("number of training examples =", X_train.shape[0])
print ("number of test examples =", X_test.shape[0])
print ("X_train shape:", X_train.shape)
print ("Y_train shape:", Y_train.shape)
print ("X_test shape:", X_test.shape)
print ("Y_test shape:", Y_test.shape)
# Out:
# number of training examples = 8005
# number of test examples = 2023
# X_train shape: (8005, 128, 128, 3)
# Y_train shape: (8005, 2)
# X_test shape: (2023, 128, 128, 3)
# Y_test shape: (2023, 2)

# %%
def identity_block(X, f, filters, stage, block):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value. We'll need this later to add back to the main path. 
    X_shortcut = X

    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(filters = F2, kernel_size = (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
   


    # Second component of main path
    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)
    

    # Third component of main path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    
    ##### SHORTCUT PATH ####
    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)
    
    return X

# %%
def ResNet50(input_shape = (224, 224, 3), classes = 2):   
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    # Stage 3
    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    # Stage 4
    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    # Stage 5
    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    # AVGPOOL.
    X = AveragePooling2D((2, 2), name='avg_pool')(X)

    # output layer
    X = Flatten()(X)

    #X = Dropout(.2)(X)

    X = Dense(classes, activation='softmax', name='fc' + str(classes), kernel_initializer = glorot_uniform(seed=0))(X)
    
    
    # Create model
    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    return model

# %%
model = ResNet50(input_shape = (ROWS, COLS, CHANNELS), classes = CLASSES)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#For example: validation_split=0.3 will cause that 30% of the training data will be used for validation.
history = model.fit(X_train, Y_train, epochs = 100, validation_split=0.2,batch_size = 32)
# Out:
# Epoch 1/100
# 201/201 [==============================] - 14s 44ms/step - loss: 1.5494 - accuracy: 0.5429 - val_loss: 0.7485 - val_accuracy: 0.5197
# Epoch 2/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.9284 - accuracy: 0.5853 - val_loss: 0.8134 - val_accuracy: 0.5191
# Epoch 3/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.7649 - accuracy: 0.6307 - val_loss: 1.2878 - val_accuracy: 0.6615
# Epoch 4/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6976 - accuracy: 0.6694 - val_loss: 0.6943 - val_accuracy: 0.6021
# Epoch 5/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6246 - accuracy: 0.6968 - val_loss: 0.7000 - val_accuracy: 0.6015
# Epoch 6/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5832 - accuracy: 0.7150 - val_loss: 0.8470 - val_accuracy: 0.6527
# Epoch 7/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6160 - accuracy: 0.7177 - val_loss: 6.7007 - val_accuracy: 0.5572
# Epoch 8/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5841 - accuracy: 0.7274 - val_loss: 2.2372 - val_accuracy: 0.5447
# Epoch 9/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6380 - accuracy: 0.6889 - val_loss: 12.7093 - val_accuracy: 0.5896
# Epoch 10/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5831 - accuracy: 0.7178 - val_loss: 0.7985 - val_accuracy: 0.6540
# Epoch 11/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5750 - accuracy: 0.7199 - val_loss: 46.4236 - val_accuracy: 0.4809
# Epoch 12/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.7606 - accuracy: 0.5489 - val_loss: 0.6918 - val_accuracy: 0.5615
# Epoch 13/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.7554 - accuracy: 0.5895 - val_loss: 0.7342 - val_accuracy: 0.5634
# Epoch 14/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.7233 - accuracy: 0.5860 - val_loss: 0.6892 - val_accuracy: 0.5597
# Epoch 15/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6716 - accuracy: 0.6218 - val_loss: 0.6692 - val_accuracy: 0.6252
# Epoch 16/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6620 - accuracy: 0.6476 - val_loss: 0.6992 - val_accuracy: 0.5671
# Epoch 17/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6599 - accuracy: 0.6512 - val_loss: 0.6373 - val_accuracy: 0.6446
# Epoch 18/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6652 - accuracy: 0.6443 - val_loss: 0.6561 - val_accuracy: 0.6015
# Epoch 19/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6362 - accuracy: 0.6655 - val_loss: 0.8047 - val_accuracy: 0.5690
# Epoch 20/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6698 - accuracy: 0.6540 - val_loss: 0.6936 - val_accuracy: 0.5984
# Epoch 21/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6441 - accuracy: 0.6657 - val_loss: 0.5985 - val_accuracy: 0.6858
# Epoch 22/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6269 - accuracy: 0.6718 - val_loss: 1.6858 - val_accuracy: 0.5659
# Epoch 23/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5989 - accuracy: 0.7025 - val_loss: 0.8393 - val_accuracy: 0.6690
# Epoch 24/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5668 - accuracy: 0.7194 - val_loss: 0.9389 - val_accuracy: 0.5728
# Epoch 25/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5535 - accuracy: 0.7281 - val_loss: 0.8467 - val_accuracy: 0.6346
# Epoch 26/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5565 - accuracy: 0.7291 - val_loss: 0.6161 - val_accuracy: 0.6677
# Epoch 27/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5989 - accuracy: 0.7055 - val_loss: 0.7024 - val_accuracy: 0.6421
# Epoch 28/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5192 - accuracy: 0.7473 - val_loss: 2.3257 - val_accuracy: 0.5453
# Epoch 29/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5011 - accuracy: 0.7616 - val_loss: 0.7140 - val_accuracy: 0.6677
# Epoch 30/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.4818 - accuracy: 0.7758 - val_loss: 0.7727 - val_accuracy: 0.6184
# Epoch 31/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.4883 - accuracy: 0.7672 - val_loss: 1.9906 - val_accuracy: 0.5240
# Epoch 32/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.4617 - accuracy: 0.7804 - val_loss: 0.5959 - val_accuracy: 0.7014
# Epoch 33/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.4633 - accuracy: 0.7811 - val_loss: 0.7748 - val_accuracy: 0.6346
# Epoch 34/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.5223 - accuracy: 0.7658 - val_loss: 0.6109 - val_accuracy: 0.6627
# Epoch 35/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.4628 - accuracy: 0.7928 - val_loss: 0.7989 - val_accuracy: 0.6359
# Epoch 36/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.4231 - accuracy: 0.8059 - val_loss: 1.5962 - val_accuracy: 0.5597
# Epoch 37/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.3974 - accuracy: 0.8235 - val_loss: 0.5795 - val_accuracy: 0.7208
# Epoch 38/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.3913 - accuracy: 0.8290 - val_loss: 0.5092 - val_accuracy: 0.7595
# Epoch 39/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.3556 - accuracy: 0.8435 - val_loss: 0.6584 - val_accuracy: 0.7114
# Epoch 40/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.3551 - accuracy: 0.8462 - val_loss: 0.8782 - val_accuracy: 0.6740
# Epoch 41/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.3071 - accuracy: 0.8666 - val_loss: 0.5749 - val_accuracy: 0.7495
# Epoch 42/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.2854 - accuracy: 0.8777 - val_loss: 0.9031 - val_accuracy: 0.6802
# Epoch 43/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.2921 - accuracy: 0.8780 - val_loss: 1.2907 - val_accuracy: 0.5696
# Epoch 44/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.3353 - accuracy: 0.8576 - val_loss: 1.0564 - val_accuracy: 0.6602
# Epoch 45/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.2464 - accuracy: 0.8954 - val_loss: 0.5942 - val_accuracy: 0.7645
# Epoch 46/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.2104 - accuracy: 0.9136 - val_loss: 0.7393 - val_accuracy: 0.7489
# Epoch 47/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.2331 - accuracy: 0.9049 - val_loss: 0.8531 - val_accuracy: 0.7039
# Epoch 48/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.6217 - accuracy: 0.6969 - val_loss: 3.9674 - val_accuracy: 0.5453
# Epoch 49/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.4524 - accuracy: 0.7900 - val_loss: 0.9031 - val_accuracy: 0.6665
# Epoch 50/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.3684 - accuracy: 0.8346 - val_loss: 0.6097 - val_accuracy: 0.7227
# Epoch 51/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.3009 - accuracy: 0.8705 - val_loss: 0.6436 - val_accuracy: 0.7089
# Epoch 52/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.2485 - accuracy: 0.9030 - val_loss: 0.8099 - val_accuracy: 0.7208
# Epoch 53/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.1665 - accuracy: 0.9358 - val_loss: 0.7222 - val_accuracy: 0.7389
# Epoch 54/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.1252 - accuracy: 0.9517 - val_loss: 1.0817 - val_accuracy: 0.7277
# Epoch 55/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.1505 - accuracy: 0.9400 - val_loss: 1.4618 - val_accuracy: 0.6871
# Epoch 56/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0997 - accuracy: 0.9613 - val_loss: 1.0178 - val_accuracy: 0.7314
# Epoch 57/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.1011 - accuracy: 0.9611 - val_loss: 1.1082 - val_accuracy: 0.7089
# Epoch 58/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0739 - accuracy: 0.9724 - val_loss: 1.2075 - val_accuracy: 0.7039
# Epoch 59/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0622 - accuracy: 0.9769 - val_loss: 1.0848 - val_accuracy: 0.7352
# Epoch 60/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0666 - accuracy: 0.9772 - val_loss: 1.5666 - val_accuracy: 0.6933
# Epoch 61/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0843 - accuracy: 0.9689 - val_loss: 1.4992 - val_accuracy: 0.6790
# Epoch 62/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0470 - accuracy: 0.9825 - val_loss: 1.0439 - val_accuracy: 0.7395
# Epoch 63/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.2937 - accuracy: 0.8955 - val_loss: 0.7728 - val_accuracy: 0.7395
# Epoch 64/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.1128 - accuracy: 0.9603 - val_loss: 1.0445 - val_accuracy: 0.6958
# Epoch 65/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.1344 - accuracy: 0.9502 - val_loss: 0.8566 - val_accuracy: 0.7477
# Epoch 66/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.1732 - accuracy: 0.9339 - val_loss: 0.8795 - val_accuracy: 0.7458
# Epoch 67/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0847 - accuracy: 0.9692 - val_loss: 0.9567 - val_accuracy: 0.7370
# Epoch 68/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0260 - accuracy: 0.9925 - val_loss: 1.0267 - val_accuracy: 0.7670
# Epoch 69/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0283 - accuracy: 0.9899 - val_loss: 1.2145 - val_accuracy: 0.7383
# Epoch 70/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 1.2585 - val_accuracy: 0.7527
# Epoch 71/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0443 - accuracy: 0.9844 - val_loss: 1.3070 - val_accuracy: 0.7420
# Epoch 72/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0260 - accuracy: 0.9916 - val_loss: 1.2515 - val_accuracy: 0.7464
# Epoch 73/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0280 - accuracy: 0.9903 - val_loss: 1.3561 - val_accuracy: 0.7327
# Epoch 74/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0508 - accuracy: 0.9806 - val_loss: 1.8108 - val_accuracy: 0.6896
# Epoch 75/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0646 - accuracy: 0.9760 - val_loss: 1.2936 - val_accuracy: 0.7439
# Epoch 76/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0920 - accuracy: 0.9672 - val_loss: 1.0670 - val_accuracy: 0.7527
# Epoch 77/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0225 - accuracy: 0.9922 - val_loss: 1.3062 - val_accuracy: 0.7433
# Epoch 78/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0284 - accuracy: 0.9891 - val_loss: 1.1137 - val_accuracy: 0.7570
# Epoch 79/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0276 - accuracy: 0.9894 - val_loss: 1.2997 - val_accuracy: 0.7651
# Epoch 80/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0300 - accuracy: 0.9884 - val_loss: 1.6455 - val_accuracy: 0.7064
# Epoch 81/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0283 - accuracy: 0.9900 - val_loss: 1.3291 - val_accuracy: 0.7414
# Epoch 82/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.1178 - accuracy: 0.9605 - val_loss: 0.9687 - val_accuracy: 0.7589
# Epoch 83/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0484 - accuracy: 0.9836 - val_loss: 1.2406 - val_accuracy: 0.7370
# Epoch 84/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0147 - accuracy: 0.9955 - val_loss: 1.2650 - val_accuracy: 0.7495
# Epoch 85/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0060 - accuracy: 0.9988 - val_loss: 1.2551 - val_accuracy: 0.7464
# Epoch 86/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 1.3103 - val_accuracy: 0.7589
# Epoch 87/100
# 201/201 [==============================] - 8s 38ms/step - loss: 0.0194 - accuracy: 0.9942 - val_loss: 3.6530 - val_accuracy: 0.6102
# Epoch 88/100
# 201/201 [==============================] - 8s 37ms/step - loss: 0.0550 - accuracy: 0.9811 - val_loss: 2.0819 - val_accuracy: 0.6427
# Epoch 89/100
# 201/201 [==============================] - 8s 37ms/step - loss: 0.0376 - accuracy: 0.9870 - val_loss: 1.8279 - val_accuracy: 0.6977
# Epoch 90/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0184 - accuracy: 0.9938 - val_loss: 1.2518 - val_accuracy: 0.7520
# Epoch 91/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0559 - accuracy: 0.9831 - val_loss: 1.1911 - val_accuracy: 0.7639
# Epoch 92/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0115 - accuracy: 0.9956 - val_loss: 1.4097 - val_accuracy: 0.7552
# Epoch 93/100
# 201/201 [==============================] - 8s 37ms/step - loss: 0.0179 - accuracy: 0.9945 - val_loss: 1.3070 - val_accuracy: 0.7433
# Epoch 94/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0093 - accuracy: 0.9966 - val_loss: 1.4124 - val_accuracy: 0.7520
# Epoch 95/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 1.8508 - val_accuracy: 0.7146
# Epoch 96/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0891 - accuracy: 0.9724 - val_loss: 1.2047 - val_accuracy: 0.7302
# Epoch 97/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0869 - accuracy: 0.9716 - val_loss: 0.9894 - val_accuracy: 0.7552
# Epoch 98/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0176 - accuracy: 0.9947 - val_loss: 1.3958 - val_accuracy: 0.7127
# Epoch 99/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0380 - accuracy: 0.9878 - val_loss: 1.2235 - val_accuracy: 0.7570
# Epoch 100/100
# 201/201 [==============================] - 7s 37ms/step - loss: 0.0163 - accuracy: 0.9952 - val_loss: 1.3076 - val_accuracy: 0.7539

# %%
plt.figure(figsize=(10,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')


plt.savefig("accuracy_graph.png")

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')

plt.savefig("loss_graph.png")

plt.show()

# %%
preds = model.evaluate(X_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 64/64 [==============================] - 1s 13ms/step - loss: 1.4338 - accuracy: 0.7415
# Loss = 1.4337925910949707
# Test Accuracy = 0.7414730787277222
